# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
train_dir='drive/My Drive/TinyML_Cookbook/Nano_desk_objects/dataset/train'

import tensorflow as tf

ds = tf.keras.utils.image_dataset_from_directory(
    directory=train_dir,
    subset='both',
    validation_split=0.2,
    seed=123,
    interpolation='bilinear',
    image_size=(48,48)
)
train_ds = ds[0]
val_ds = ds[1]
# Out:
# Found 74 files belonging to 3 classes.
# Using 60 files for training.
# Using 14 files for validation.

# %%
class_names = train_ds.class_names
num_classes = len(class_names)

rescale = tf.keras.layers.Rescaling(1./255, offset=-1)
train_ds = train_ds.map(lambda x, y: (rescale(x), y))
val_ds = val_ds.map(lambda x, y: (rescale(x), y))

# %%
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2

base_model = MobileNetV2(input_shape=(48,48,3), include_top=False, weights='imagenet',
                         alpha=0.35)

base_model.trainable = False
feat_extr = base_model
# Out:
# <ipython-input-4-0f7a9a3e3172>:3: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNetV2(input_shape=(48,48,3), include_top=False, weights='imagenet',
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_0.35_224_no_top.h5
# 2019640/2019640 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
print('num. weights:', len(base_model.weights))
print('num. trainable weights:', len(base_model.trainable_weights))
print('num. non-trainable weights:', len(base_model.non_trainable_weights))
# Out:
# num. weights: 260
# num. trainable weights: 0
# num. non-trainable weights: 260

# %%
layers = tf.keras.layers
augmen = tf.keras.Sequential([
    layers.RandomRotation(0.2),
    layers.RandomFlip('horizontal')
])

train_ds = train_ds.map(lambda x, y: (augmen(x), y))
val_ds = val_ds.map(lambda x, y: (augmen(x), y))

# %%
global_avg_layer = layers.GlobalAveragePooling2D()
dense_layer = layers.Dense(num_classes, activation='softmax')

x = global_avg_layer(feat_extr.layers[-1].output)
x = layers.Dropout(0.2)(x)
outputs = dense_layer(x)

model = tf.keras.Model(inputs=feat_extr.inputs,
                       outputs=outputs)

# %%
lr = 0.0005
opt_f = tf.keras.optimizers.Adam(learning_rate=lr)
loss_f = tf.losses.SparseCategoricalCrossentropy(from_logits=False)
model.compile(optimizer=opt_f,
              loss=loss_f,
              metrics=['accuracy'])

# %%
model.fit(train_ds,
          validation_data=val_ds,
          epochs=20)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(None, 48, 48, 3))
#   warnings.warn(msg)
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 18s 7s/step - accuracy: 0.5639 - loss: 0.7871 - val_accuracy: 0.5714 - val_loss: 0.7078
# Epoch 2/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 9s 307ms/step - accuracy: 0.6410 - loss: 0.6670 - val_accuracy: 0.7143 - val_loss: 0.9645
# Epoch 3/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 299ms/step - accuracy: 0.6646 - loss: 0.6121 - val_accuracy: 0.5000 - val_loss: 0.8242
# Epoch 4/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 318ms/step - accuracy: 0.7069 - loss: 0.7074 - val_accuracy: 0.5714 - val_loss: 0.7733
# Epoch 5/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 295ms/step - accuracy: 0.6632 - loss: 0.6859 - val_accuracy: 0.6429 - val_loss: 0.6518
# Epoch 6/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 332ms/step - accuracy: 0.7493 - loss: 0.4997 - val_accuracy: 0.7857 - val_loss: 0.6084
# Epoch 7/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 331ms/step - accuracy: 0.6306 - loss: 0.7791 - val_accuracy: 0.6429 - val_loss: 0.6077
# Epoch 8/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 292ms/step - accuracy: 0.7826 - loss: 0.4857 - val_accuracy: 0.7857 - val_loss: 0.5282
# Epoch 9/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 304ms/step - accuracy: 0.6750 - loss: 0.5597 - val_accuracy: 0.6429 - val_loss: 0.5046
# Epoch 10/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 298ms/step - accuracy: 0.7493 - loss: 0.5579 - val_accuracy: 0.6429 - val_loss: 0.5416
# Epoch 11/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 564ms/step - accuracy: 0.8146 - loss: 0.4754 - val_accuracy: 0.5000 - val_loss: 0.7327
# Epoch 12/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 505ms/step - accuracy: 0.8042 - loss: 0.4624 - val_accuracy: 0.7857 - val_loss: 0.4456
# Epoch 13/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 498ms/step - accuracy: 0.7403 - loss: 0.5174 - val_accuracy: 0.7143 - val_loss: 0.4245
# Epoch 14/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 615ms/step - accuracy: 0.8361 - loss: 0.3882 - val_accuracy: 0.8571 - val_loss: 0.3107
# Epoch 15/20
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 321ms/step - accuracy: 0

converter.optimizations = [tf.lite.Optimize.DEFAULT]
converter.target_spec.supported_ops = [tf.lite.OpsSet.TFLITE_BUILTINS_INT8]
converter.inference_input_type = tf.int8

tfl_model = converter.convert()
# Out:
# Found 15 files belonging to 2 classes.

# %%
interp = tf.lite.Interpreter(model_content=tfl_model)

interp.allocate_tensors()

i_details = interp.get_input_details()[0]
o_details = interp.get_output_details()[0]

i_quant = i_details['quantization_parameters']
i_scale = i_quant['scales'][0]
i_zero_point = i_quant['zero_points'][0]

# %%
import numpy as np

test_ds0 = test_ds.unbatch()

num_correct_samples = 0
num_samples = len(list(test_ds0.batch(1)))

for i_value, o_value in test_ds0.batch(1):
  i_value = (i_value/i_scale) + i_zero_point
  i_value = tf.cast(i_value, dtype=tf.int8)
  interp.set_tensor(i_details['index'], i_value)
  interp.invoke()

  o_pred = interp.get_tensor(o_details['index'])[0]
  if np.argmax(o_pred) == o_value:
    num_correct_samples += 1

print('Accuracy:', num_correct_samples/num_samples)
# Out:
# Accuracy: 0.6

# %%
open('model.tflite', 'wb').write(tfl_model)
# !apt-get update && apt-get -qq install xxd
# !pip install netron
# !xxd -i model.tflite > model.h
# !sed -i 's/unsigned char/const unsigned char/g' model.h
# !sed -i 's/const/alignas(8) const/g' model.h
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:3 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2,844 kB]
# Get:8 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,244 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [4,118 kB]
# Get:11 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,605 kB]
# Get:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Hit:13 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:14 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:15 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,696 kB]
# Get:16 https://r2u.stat.illinois.edu/ubuntu jammy/main all Packages [8,848 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,543 kB]
# Get:18 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy/main amd64 Packages [47.1 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [3,154 kB]
# Fetched 26.4 MB in 3s (10.1 MB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)

# %%
size_tfl_model = len(tfl_model)
print(size_tfl_model, "bytes")

@tf.function
def func(x):
    return model(x)

model_func = func.get_concrete_function(np.zeros((0,48,48,3), dtype=np.uint8))
ops = model_func.graph.get_operations()

unique_ops = set()

for op in ops:
    unique_ops.add(op)

for op in unique_ops:
    print(f'Name: {op.name}')
    print(f'Op: {op.type}')
    print()
# Out:
# 619840 bytes
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['keras_tensor']
# Received: inputs=Tensor(shape=(0, 48, 48, 3))
#   warnings.warn(msg)
# Name: functional_1_1/expanded_conv_depthwise_BN_1/batchnorm/Rsqrt
# Op: Rsqrt
#
# Name: functional_1_1/block_9_project_BN_1/Cast_1/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/global_average_pooling2d_1/Mean
# Op: Mean
#
# Name: functional_1_1/block_9_project_1/convolution/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/dense_1/BiasAdd
# Op: BiasAdd
#
# Name: functional_1_1/expanded_conv_depthwise_BN_1/Cast_2/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_2_depthwise_BN_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/block_9_project_BN_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/dense_1/BiasAdd/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_9_project_BN_1/Cast/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/out_relu_1/Relu6
# Op: Relu6
#
# Name: functional_1_1/expanded_conv_depthwise_BN_1/Cast_1/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_9_project_BN_1/Cast_2/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_5_project_BN_1/batchnorm/add/y
# Op: Const
#
# Name: functional_1_1/block_9_project_BN_1/batchnorm/Rsqrt
# Op: Rsqrt
#
# Name: functional_1_1/global_average_pooling2d_1/Mean/reduction_indices
# Op: Const
#
# Name: functional_1_1/expanded_conv_depthwise_BN_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/block_2_project_BN_1/Cast/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_4_add_1/Add
# Op: AddV2
#
# Name: functional_1_1/expanded_conv_depthwise_BN_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_2_project_BN_1/Cast_2/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_9_project_BN_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/dense_1/Cast/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/expanded_conv_depthwise_BN_1/batchnorm/mul
# Op: Mul
#
# Name: functional_1_1/block_2_project_BN_1/batchnorm/add/y
# Op: Const
#
# Name: functional_1_1/block_5_expand_BN_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/block_9_project_BN_1/batchnorm/mul
# Op: Mul
#
# Name: functional_1_1/block_5_expand_BN_1/batchnorm/add/y
# Op: Const
#
# Name: functional_1_1/block_9_project_BN_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/expanded_conv_depthwise_BN_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/block_2_project_BN_1/Cast_3/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_5_expand_BN_1/Cast_1/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_9_project_BN_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/dense_1/Softmax
# Op: Softmax
#
# Name: functional_1_1/block_2_project_1/convolution/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_5_expand_BN_1/Cast_2/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_9_project_BN_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/block_2_project_BN_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_5_expand_BN_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/block_9_project_BN_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/dense_1/BiasAdd/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_2_project_BN_1/Cast_1/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_5_expand_BN_1/Cast/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/dense_1/MatMul
# Op: MatMul
#
# Name: functional_1_1/block_5_expand_1/convolution/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/expanded_conv_depthwise_BN_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/block_5_expand_BN_1/Cast_2/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/expanded_conv_depthwise_BN_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/block_2_project_1/convolution/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_6_depthwise_1/depthwise/Shape
# Op: Const
#
# Name: functional_1_1/block_2_project_BN_1/batchnorm/Rsqrt
# Op: Rsqrt
#
# Name: functional_1_1/block_5_expand_BN_1/Cast_3/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_9_add_1/Add
# Op: AddV2
#
# Name: functional_1_1/expanded_conv_depthwise_BN_1/Cast_2/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_5_expand_BN_1/Cast_1/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_10_expand_BN_1/batchnorm/add/y
# Op: Const
#
# Name: functional_1_1/expanded_conv_depthwise_BN_1/Cast_3/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_5_expand_1/convolution/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_10_expand_BN_1/Cast_3/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_2_project_BN_1/Cast_1/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_5_expand_BN_1/batchnorm/Rsqrt
# Op: Rsqrt
#
# Name: functional_1_1/block_10_expand_BN_1/Cast_1/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/expanded_conv_depthwise_BN_1/Cast/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_2_project_1/convolution
# Op: Conv2D
#
# Name: functional_1_1/block_10_expand_BN_1/Cast_2/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_2_project_BN_1/Cast_2/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_5_expand_BN_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/block_10_expand_BN_1/Cast/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_2_project_BN_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/block_5_expand_BN_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_10_expand_1/convolution/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/expanded_conv_depthwise_1/depthwise
# Op: DepthwiseConv2dNative
#
# Name: functional_1_1/block_2_project_BN_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_5_expand_relu_1/Relu6
# Op: Relu6
#
# Name: functional_1_1/block_10_expand_BN_1/Cast_1/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/expanded_conv_depthwise_BN_1/batchnorm/add/y
# Op: Const
#
# Name: functional_1_1/block_5_expand_BN_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/expanded_conv_depthwise_BN_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/block_2_project_BN_1/batchnorm/mul
# Op: Mul
#
# Name: functional_1_1/block_5_depthwise_BN_1/Cast_1/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_10_expand_BN_1/Cast_2/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_2_project_BN_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/block_5_expand_BN_1/batchnorm/mul
# Op: Mul
#
# Name: functional_1_1/block_10_expand_BN_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_2_project_BN_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/block_5_expand_BN_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/block_10_expand_1/convolution/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_2_project_BN_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/expanded_conv_project_BN_1/batchnorm/add/y
# Op: Const
#
# Name: functional_1_1/block_2_project_BN_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/block_10_expand_BN_1/batchnorm/Rsqrt
# Op: Rsqrt
#
# Name: functional_1_1/block_5_depthwise_1/depthwise/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_10_depthwise_BN_1/Cast_1/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_5_depthwise_1/depthwise/Shape
# Op: Const
#
# Name: functional_1_1/block_10_expand_1/convolution
# Op: Conv2D
#
# Name: functional_1_1/block_10_expand_BN_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/block_5_depthwise_BN_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_10_expand_BN_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_5_depthwise_1/depthwise/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_10_expand_relu_1/Relu6
# Op: Relu6
#
# Name: functional_1_1/expanded_conv_project_BN_1/Cast_1/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_2_add_1/Add
# Op: AddV2
#
# Name: functional_1_1/block_5_depthwise_1/depthwise/dilation_rate
# Op: Const
#
# Name: functional_1_1/block_10_expand_BN_1/batchnorm/mul
# Op: Mul
#
# Name: functional_1_1/block_5_depthwise_BN_1/batchnorm/Rsqrt
# Op: Rsqrt
#
# Name: functional_1_1/block_10_expand_BN_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/expanded_conv_project_BN_1/Cast/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_10_expand_BN_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/expanded_conv_project_1/convolution/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_3_expand_BN_1/Cast/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_10_expand_BN_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/block_3_expand_BN_1/Cast_2/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_10_expand_BN_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/block_3_expand_BN_1/batchnorm/add/y
# Op: Const
#
# Name: functional_1_1/block_5_depthwise_BN_1/Cast_2/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_10_depthwise_1/depthwise/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_5_depthwise_BN_1/Cast_3/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/expanded_conv_project_BN_1/Cast_2/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_3_expand_BN_1/Cast_3/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_5_depthwise_1/depthwise
# Op: DepthwiseConv2dNative
#
# Name: functional_1_1/block_10_depthwise_1/depthwise/Shape
# Op: Const
#
# Name: functional_1_1/expanded_conv_depthwise_relu_1/Relu6
# Op: Relu6
#
# Name: functional_1_1/block_3_expand_1/convolution/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_5_depthwise_BN_1/Cast/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/expanded_conv_project_BN_1/Cast_2/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_3_expand_BN_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_5_depthwise_BN_1/batchnorm/add/y
# Op: Const
#
# Name: functional_1_1/block_10_depthwise_BN_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/expanded_conv_project_BN_1/Cast_3/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_3_expand_BN_1/Cast_1/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_5_depthwise_BN_1/Cast_1/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_10_depthwise_1/depthwise/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_10_depthwise_1/depthwise/dilation_rate
# Op: Const
#
# Name: functional_1_1/expanded_conv_project_1/convolution/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_5_depthwise_BN_1/Cast_2/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_10_depthwise_BN_1/batchnorm/Rsqrt
# Op: Rsqrt
#
# Name: functional_1_1/block_3_expand_1/convolution/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_5_depthwise_BN_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/expanded_conv_project_BN_1/Cast_1/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_3_expand_BN_1/batchnorm/Rsqrt
# Op: Rsqrt
#
# Name: functional_1_1/block_5_depthwise_BN_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/expanded_conv_project_BN_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_3_expand_relu_1/Relu6
# Op: Relu6
#
# Name: functional_1_1/block_5_expand_BN_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_5_depthwise_relu_1/Relu6
# Op: Relu6
#
# Name: functional_1_1/expanded_conv_project_BN_1/batchnorm/Rsqrt
# Op: Rsqrt
#
# Name: functional_1_1/block_5_depthwise_BN_1/batchnorm/mul
# Op: Mul
#
# Name: functional_1_1/block_10_depthwise_BN_1/Cast_2/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_3_expand_BN_1/Cast_1/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_5_expand_1/convolution
# Op: Conv2D
#
# Name: functional_1_1/block_5_depthwise_BN_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/block_10_depthwise_BN_1/Cast_3/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/expanded_conv_project_1/convolution
# Op: Conv2D
#
# Name: functional_1_1/block_3_expand_1/convolution
# Op: Conv2D
#
# Name: functional_1_1/block_5_depthwise_BN_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/block_10_depthwise_1/depthwise
# Op: DepthwiseConv2dNative
#
# Name: functional_1_1/expanded_conv_project_BN_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/block_3_expand_BN_1/Cast_2/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_5_depthwise_BN_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/block_10_depthwise_BN_1/Cast/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/expanded_conv_project_BN_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_3_expand_BN_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/block_5_depthwise_BN_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/block_10_depthwise_BN_1/batchnorm/add/y
# Op: Const
#
# Name: functional_1_1/block_3_expand_BN_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_10_depthwise_BN_1/Cast_1/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/expanded_conv_project_BN_1/batchnorm/mul
# Op: Mul
#
# Name: functional_1_1/block_5_project_BN_1/Cast/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/expanded_conv_project_BN_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/block_3_expand_BN_1/batchnorm/mul
# Op: Mul
#
# Name: functional_1_1/block_5_project_BN_1/Cast_2/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_10_depthwise_BN_1/Cast_2/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/expanded_conv_project_BN_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/block_3_expand_BN_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/block_5_project_BN_1/Cast_3/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_10_depthwise_BN_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/expanded_conv_project_BN_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/block_3_expand_BN_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/block_5_project_1/convolution/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_10_depthwise_BN_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/expanded_conv_project_BN_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/block_3_expand_BN_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/block_10_depthwise_relu_1/Relu6
# Op: Relu6
#
# Name: functional_1_1/block_3_expand_BN_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/block_5_project_BN_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_10_depthwise_BN_1/batchnorm/mul
# Op: Mul
#
# Name: functional_1_1/block_5_project_BN_1/Cast_1/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_10_depthwise_BN_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/block_1_depthwise_BN_1/Cast_2/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_9_project_BN_1/batchnorm/add/y
# Op: Const
#
# Name: functional_1_1/block_10_depthwise_BN_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/block_3_depthwise_BN_1/Cast_2/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_10_depthwise_BN_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/block_1_expand_BN_1/Cast/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_3_depthwise_1/depthwise/Shape
# Op: Const
#
# Name: functional_1_1/block_5_project_1/convolution/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_10_depthwise_BN_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/bn_Conv1_1/Cast_1/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_1_expand_BN_1/Cast_2/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_3_depthwise_1/depthwise/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_5_project_BN_1/batchnorm/Rsqrt
# Op: Rsqrt
#
# Name: functional_1_1/block_10_project_BN_1/Cast_3/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_1_expand_BN_1/batchnorm/add/y
# Op: Const
#
# Name: functional_1_1/block_11_expand_BN_1/Cast_3/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_10_project_BN_1/Cast/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_1_expand_BN_1/Cast_3/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_3_depthwise_BN_1/Cast_3/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_5_project_BN_1/Cast_1/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_10_project_BN_1/Cast_1/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_1_expand_1/convolution/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_3_pad_1/Const
# Op: Const
#
# Name: functional_1_1/block_5_project_1/convolution
# Op: Conv2D
#
# Name: functional_1_1/block_10_project_BN_1/Cast_2/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_1_expand_BN_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_3_pad_1/Pad
# Op: Pad
#
# Name: functional_1_1/block_5_project_BN_1/Cast_2/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_10_project_1/convolution/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_1_expand_BN_1/Cast_1/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_3_depthwise_BN_1/Cast_1/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_5_project_BN_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/block_1_depthwise_1/depthwise/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_5_project_BN_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_10_project_BN_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_1_expand_relu_1/Relu6
# Op: Relu6
#
# Name: functional_1_1/block_3_depthwise_1/depthwise/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_10_project_BN_1/Cast_1/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_1_expand_1/convolution/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_3_depthwise_1/depthwise/dilation_rate
# Op: Const
#
# Name: functional_1_1/block_5_project_BN_1/batchnorm/mul
# Op: Mul
#
# Name: functional_1_1/block_10_project_BN_1/batchnorm/Rsqrt
# Op: Rsqrt
#
# Name: functional_1_1/block_1_expand_BN_1/batchnorm/Rsqrt
# Op: Rsqrt
#
# Name: functional_1_1/block_3_depthwise_BN_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_5_project_BN_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/block_10_project_1/convolution/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_3_depthwise_BN_1/batchnorm/Rsqrt
# Op: Rsqrt
#
# Name: functional_1_1/block_5_project_BN_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/block_1_expand_BN_1/Cast_1/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_5_project_BN_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/block_1_expand_1/convolution
# Op: Conv2D
#
# Name: functional_1_1/block_5_project_BN_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/block_1_expand_BN_1/Cast_2/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_3_depthwise_BN_1/Cast/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_10_project_BN_1/batchnorm/add/y
# Op: Const
#
# Name: functional_1_1/block_1_expand_BN_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/block_3_depthwise_BN_1/batchnorm/add/y
# Op: Const
#
# Name: functional_1_1/block_10_project_1/convolution
# Op: Conv2D
#
# Name: functional_1_1/block_1_expand_BN_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_3_depthwise_1/depthwise
# Op: DepthwiseConv2dNative
#
# Name: functional_1_1/Conv1_1/convolution
# Op: Conv2D
#
# Name: functional_1_1/block_3_depthwise_BN_1/Cast_1/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_10_project_BN_1/Cast_2/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_1_expand_BN_1/batchnorm/mul
# Op: Mul
#
# Name: functional_1_1/block_5_add_1/Add
# Op: AddV2
#
# Name: functional_1_1/block_10_project_BN_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/block_1_expand_BN_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/block_3_depthwise_BN_1/Cast_2/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_10_project_BN_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_1_expand_BN_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/block_3_depthwise_BN_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/block_1_expand_BN_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/block_3_depthwise_BN_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_6_expand_BN_1/Cast/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_10_project_BN_1/batchnorm/mul
# Op: Mul
#
# Name: functional_1_1/block_1_expand_BN_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/block_3_depthwise_relu_1/Relu6
# Op: Relu6
#
# Name: functional_1_1/block_6_expand_BN_1/Cast_2/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_10_project_BN_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/bn_Conv1_1/Cast_2/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_1_depthwise_BN_1/Cast_1/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_3_depthwise_BN_1/batchnorm/mul
# Op: Mul
#
# Name: functional_1_1/block_6_expand_BN_1/batchnorm/add/y
# Op: Const
#
# Name: functional_1_1/block_10_project_BN_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/block_3_depthwise_BN_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/block_10_project_BN_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/block_3_depthwise_BN_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/block_6_expand_BN_1/Cast_3/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_10_project_BN_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/block_1_pad_1/Const
# Op: Const
#
# Name: functional_1_1/block_3_depthwise_BN_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/block_6_expand_1/convolution/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_11_expand_BN_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/bn_Conv1_1/Cast/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_1_pad_1/Pad
# Op: Pad
#
# Name: functional_1_1/block_3_depthwise_BN_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/block_6_expand_BN_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_11_expand_BN_1/Cast/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_1_depthwise_1/depthwise/Shape
# Op: Const
#
# Name: functional_1_1/block_6_expand_BN_1/Cast_1/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_11_expand_BN_1/Cast_1/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/bn_Conv1_1/Cast_2/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_1_depthwise_relu_1/Relu6
# Op: Relu6
#
# Name: functional_1_1/block_3_project_BN_1/Cast_3/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_11_expand_BN_1/Cast_2/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_1_depthwise_BN_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_11_expand_1/convolution/ReadVariableOp
# Op: ReadVariableOp
#
# Name: NoOp
# Op: NoOp
#
# Name: functional_1_1/block_3_project_BN_1/Cast/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_1_depthwise_1/depthwise/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_6_expand_1/convolution/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_11_expand_BN_1/batchnorm/Rsqrt
# Op: Rsqrt
#
# Name: functional_1_1/block_1_depthwise_1/depthwise/dilation_rate
# Op: Const
#
# Name: functional_1_1/block_3_project_BN_1/Cast_1/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_6_expand_BN_1/batchnorm/Rsqrt
# Op: Rsqrt
#
# Name: functional_1_1/block_11_expand_BN_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_1_depthwise_BN_1/batchnorm/Rsqrt
# Op: Rsqrt
#
# Name: functional_1_1/block_3_project_BN_1/Cast_2/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_6_depthwise_BN_1/batchnorm/Rsqrt
# Op: Rsqrt
#
# Name: functional_1_1/block_11_expand_BN_1/Cast_1/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_2_depthwise_BN_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/block_3_project_1/convolution/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_11_depthwise_BN_1/Cast_2/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_6_expand_BN_1/Cast_1/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_11_expand_1/convolution/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_3_project_BN_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_6_expand_1/convolution
# Op: Conv2D
#
# Name: functional_1_1/Conv1_1/convolution/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_1_depthwise_BN_1/Cast_2/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_3_project_BN_1/Cast_1/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_6_expand_BN_1/Cast_2/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_11_expand_relu_1/Relu6
# Op: Relu6
#
# Name: functional_1_1/block_1_depthwise_BN_1/Cast_3/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_3_project_BN_1/batchnorm/Rsqrt
# Op: Rsqrt
#
# Name: functional_1_1/block_6_expand_BN_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/block_1_depthwise_1/depthwise
# Op: DepthwiseConv2dNative
#
# Name: functional_1_1/block_3_project_1/convolution/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_6_expand_BN_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_1_depthwise_BN_1/Cast/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_6_expand_relu_1/Relu6
# Op: Relu6
#
# Name: functional_1_1/block_11_expand_1/convolution
# Op: Conv2D
#
# Name: functional_1_1/block_1_depthwise_BN_1/Cast_1/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_6_expand_BN_1/batchnorm/mul
# Op: Mul
#
# Name: functional_1_1/block_11_expand_BN_1/batchnorm/add/y
# Op: Const
#
# Name: functional_1_1/block_1_depthwise_BN_1/batchnorm/add/y
# Op: Const
#
# Name: functional_1_1/block_6_expand_BN_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/block_11_expand_BN_1/Cast_2/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_3_project_BN_1/batchnorm/add/y
# Op: Const
#
# Name: functional_1_1/block_6_expand_BN_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/block_1_depthwise_BN_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/block_3_project_1/convolution
# Op: Conv2D
#
# Name: functional_1_1/block_6_expand_BN_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/block_11_expand_BN_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_1_depthwise_BN_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_6_expand_BN_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/block_11_expand_BN_1/batchnorm/mul
# Op: Mul
#
# Name: Identity
# Op: Identity
#
# Name: functional_1_1/block_3_project_BN_1/Cast_2/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_11_expand_BN_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/block_1_depthwise_BN_1/batchnorm/mul
# Op: Mul
#
# Name: functional_1_1/block_3_project_BN_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/block_6_depthwise_BN_1/Cast_3/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_11_expand_BN_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/block_1_depthwise_BN_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/block_3_project_BN_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_6_depthwise_1/depthwise/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_11_expand_BN_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/block_1_depthwise_BN_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/block_11_expand_BN_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/block_1_depthwise_BN_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/block_3_project_BN_1/batchnorm/mul
# Op: Mul
#
# Name: functional_1_1/block_1_depthwise_BN_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/block_3_project_BN_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/block_6_depthwise_BN_1/Cast_1/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_11_depthwise_1/depthwise/ReadVariableOp
# Op: ReadVariableOp
#
# Name: x
# Op: Placeholder
#
# Name: functional_1_1/block_3_project_BN_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/block_6_pad_1/Const
# Op: Const
#
# Name: functional_1_1/block_11_depthwise_BN_1/Cast_3/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/Conv_1_bn_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/block_3_project_BN_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/block_6_pad_1/Pad
# Op: Pad
#
# Name: functional_1_1/block_11_depthwise_1/depthwise/Shape
# Op: Const
#
# Name: functional_1_1/block_3_project_BN_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/block_6_depthwise_BN_1/Cast_2/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_11_depthwise_BN_1/Cast_1/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_1_project_BN_1/Cast/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_6_depthwise_1/depthwise/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_11_depthwise_1/depthwise/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_1_project_BN_1/Cast_2/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_4_expand_BN_1/Cast/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_6_depthwise_BN_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_11_depthwise_1/depthwise/dilation_rate
# Op: Const
#
# Name: functional_1_1/block_1_project_BN_1/Cast_3/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_4_expand_BN_1/Cast_2/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_6_depthwise_1/depthwise/dilation_rate
# Op: Const
#
# Name: functional_1_1/block_11_depthwise_BN_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_4_expand_BN_1/batchnorm/add/y
# Op: Const
#
# Name: functional_1_1/block_6_depthwise_relu_1/Relu6
# Op: Relu6
#
# Name: functional_1_1/block_11_depthwise_BN_1/batchnorm/Rsqrt
# Op: Rsqrt
#
# Name: functional_1_1/block_1_project_BN_1/Cast_1/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_1_project_1/convolution/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_4_expand_BN_1/Cast_3/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_6_depthwise_BN_1/batchnorm/add/y
# Op: Const
#
# Name: functional_1_1/block_1_project_BN_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_4_expand_1/convolution/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_6_depthwise_BN_1/Cast/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_11_depthwise_BN_1/Cast/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_1_project_BN_1/Cast_1/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_4_expand_BN_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_6_depthwise_1/depthwise
# Op: DepthwiseConv2dNative
#
# Name: functional_1_1/block_11_depthwise_BN_1/batchnorm/add/y
# Op: Const
#
# Name: functional_1_1/block_4_expand_BN_1/Cast_1/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_6_depthwise_BN_1/Cast_1/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_11_depthwise_1/depthwise
# Op: DepthwiseConv2dNative
#
# Name: functional_1_1/block_4_depthwise_BN_1/batchnorm/Rsqrt
# Op: Rsqrt
#
# Name: functional_1_1/block_11_depthwise_BN_1/Cast_1/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_1_project_1/convolution/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_6_depthwise_BN_1/Cast_2/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_1_project_BN_1/batchnorm/Rsqrt
# Op: Rsqrt
#
# Name: functional_1_1/block_4_expand_1/convolution/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_6_depthwise_BN_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/block_11_depthwise_BN_1/Cast_2/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_4_expand_BN_1/batchnorm/Rsqrt
# Op: Rsqrt
#
# Name: functional_1_1/block_6_depthwise_BN_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_11_depthwise_BN_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/block_11_depthwise_BN_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/Cast
# Op: Cast
#
# Name: functional_1_1/block_1_project_BN_1/batchnorm/add/y
# Op: Const
#
# Name: functional_1_1/block_6_depthwise_BN_1/batchnorm/mul
# Op: Mul
#
# Name: functional_1_1/block_11_depthwise_relu_1/Relu6
# Op: Relu6
#
# Name: functional_1_1/block_1_project_1/convolution
# Op: Conv2D
#
# Name: functional_1_1/block_4_expand_BN_1/Cast_1/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_6_depthwise_BN_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/block_11_depthwise_BN_1/batchnorm/mul
# Op: Mul
#
# Name: functional_1_1/block_1_project_BN_1/Cast_2/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_4_expand_1/convolution
# Op: Conv2D
#
# Name: functional_1_1/block_6_depthwise_BN_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/block_11_depthwise_BN_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/block_1_project_BN_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/block_4_expand_BN_1/Cast_2/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_6_depthwise_BN_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/block_11_depthwise_BN_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/bn_Conv1_1/Cast_3/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_1_project_BN_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_4_expand_BN_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/block_6_depthwise_BN_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/block_11_depthwise_BN_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/block_4_expand_BN_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_11_depthwise_BN_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/Conv1_1/convolution/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_1_project_BN_1/batchnorm/mul
# Op: Mul
#
# Name: functional_1_1/block_4_expand_relu_1/Relu6
# Op: Relu6
#
# Name: functional_1_1/block_6_project_BN_1/Cast/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_11_project_BN_1/Cast_3/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_1_project_BN_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/block_4_expand_BN_1/batchnorm/mul
# Op: Mul
#
# Name: functional_1_1/block_6_project_BN_1/Cast_2/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_1_project_BN_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/block_4_expand_BN_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/block_6_project_BN_1/batchnorm/add/y
# Op: Const
#
# Name: functional_1_1/block_11_project_BN_1/Cast/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_1_project_BN_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/block_4_expand_BN_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/block_11_project_BN_1/Cast_1/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_1_project_BN_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/block_4_expand_BN_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/block_6_project_BN_1/Cast_3/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_11_project_BN_1/Cast_2/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_4_expand_BN_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/block_6_project_1/convolution/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_11_project_1/convolution/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_6_project_BN_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_4_depthwise_1/depthwise/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_6_project_BN_1/Cast_1/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_11_project_BN_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_4_depthwise_BN_1/Cast_2/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_11_project_BN_1/Cast_1/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_2_expand_BN_1/Cast/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_4_depthwise_1/depthwise/Shape
# Op: Const
#
# Name: functional_1_1/block_11_project_BN_1/batchnorm/Rsqrt
# Op: Rsqrt
#
# Name: functional_1_1/block_2_expand_BN_1/Cast_2/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_4_depthwise_BN_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_6_project_1/convolution/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_11_project_1/convolution/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_2_expand_BN_1/batchnorm/add/y
# Op: Const
#
# Name: functional_1_1/block_4_depthwise_BN_1/Cast_1/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_6_project_BN_1/batchnorm/Rsqrt
# Op: Rsqrt
#
# Name: functional_1_1/block_2_expand_1/convolution/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_4_depthwise_1/depthwise/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_2_expand_BN_1/Cast_3/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_4_depthwise_1/depthwise/dilation_rate
# Op: Const
#
# Name: functional_1_1/block_2_expand_BN_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_6_project_BN_1/Cast_1/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_11_project_BN_1/batchnorm/add/y
# Op: Const
#
# Name: functional_1_1/bn_Conv1_1/Cast_1/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_2_expand_BN_1/Cast_1/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_6_project_1/convolution
# Op: Conv2D
#
# Name: functional_1_1/block_11_project_1/convolution
# Op: Conv2D
#
# Name: functional_1_1/bn_Conv1_1/batchnorm/mul
# Op: Mul
#
# Name: functional_1_1/block_6_project_BN_1/Cast_2/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_6_project_BN_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/block_11_project_BN_1/Cast_2/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_2_expand_1/convolution/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_4_depthwise_BN_1/Cast_3/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_6_project_BN_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_11_project_BN_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/block_2_expand_BN_1/batchnorm/Rsqrt
# Op: Rsqrt
#
# Name: functional_1_1/block_4_depthwise_BN_1/Cast/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_11_project_BN_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_2_expand_relu_1/Relu6
# Op: Relu6
#
# Name: functional_1_1/block_4_depthwise_1/depthwise
# Op: DepthwiseConv2dNative
#
# Name: functional_1_1/block_6_project_BN_1/batchnorm/mul
# Op: Mul
#
# Name: functional_1_1/block_4_depthwise_BN_1/batchnorm/add/y
# Op: Const
#
# Name: functional_1_1/block_6_project_BN_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/block_11_project_BN_1/batchnorm/mul
# Op: Mul
#
# Name: functional_1_1/block_2_expand_BN_1/Cast_1/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_4_depthwise_BN_1/Cast_1/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_6_project_BN_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/block_11_project_BN_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/block_2_expand_1/convolution
# Op: Conv2D
#
# Name: functional_1_1/block_6_project_BN_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/block_11_project_BN_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/block_2_expand_BN_1/Cast_2/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_4_depthwise_BN_1/Cast_2/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_6_project_BN_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/block_11_project_BN_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/block_2_expand_BN_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/block_4_depthwise_BN_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/block_11_project_BN_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/block_2_expand_BN_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_4_depthwise_BN_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_4_depthwise_relu_1/Relu6
# Op: Relu6
#
# Name: functional_1_1/block_2_expand_BN_1/batchnorm/mul
# Op: Mul
#
# Name: functional_1_1/block_4_depthwise_BN_1/batchnorm/mul
# Op: Mul
#
# Name: functional_1_1/block_7_expand_BN_1/Cast/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_2_expand_BN_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/block_4_depthwise_BN_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/block_7_expand_BN_1/Cast_2/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_12_expand_BN_1/Cast_3/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_2_expand_BN_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/block_4_depthwise_BN_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/block_7_expand_BN_1/batchnorm/add/y
# Op: Const
#
# Name: functional_1_1/block_11_add_1/Add
# Op: AddV2
#
# Name: functional_1_1/bn_Conv1_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_2_expand_BN_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/block_4_depthwise_BN_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/block_2_expand_BN_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/block_4_depthwise_BN_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/block_7_expand_BN_1/Cast_3/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_12_expand_BN_1/Cast/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_2_depthwise_BN_1/batchnorm/Rsqrt
# Op: Rsqrt
#
# Name: functional_1_1/block_7_expand_1/convolution/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_12_expand_BN_1/Cast_1/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_4_project_BN_1/Cast_3/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_7_expand_BN_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_12_expand_BN_1/Cast_2/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_2_depthwise_1/depthwise/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_4_project_BN_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/block_7_expand_BN_1/Cast_1/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_12_expand_1/convolution/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_2_depthwise_BN_1/Cast_2/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_4_project_BN_1/Cast/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_2_depthwise_1/depthwise/Shape
# Op: Const
#
# Name: functional_1_1/block_4_project_BN_1/Cast_1/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_7_depthwise_relu_1/Relu6
# Op: Relu6
#
# Name: functional_1_1/block_12_expand_BN_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_2_depthwise_BN_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_4_project_BN_1/Cast_2/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_7_expand_1/convolution/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_12_expand_BN_1/Cast_1/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_2_depthwise_BN_1/Cast_1/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_4_project_1/convolution/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_7_expand_BN_1/batchnorm/Rsqrt
# Op: Rsqrt
#
# Name: functional_1_1/block_12_expand_BN_1/batchnorm/Rsqrt
# Op: Rsqrt
#
# Name: functional_1_1/block_2_depthwise_1/depthwise/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_12_expand_1/convolution/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_2_depthwise_1/depthwise/dilation_rate
# Op: Const
#
# Name: functional_1_1/block_4_project_BN_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_2_depthwise_BN_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/block_4_project_BN_1/Cast_1/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_7_expand_BN_1/Cast_1/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_4_project_BN_1/batchnorm/Rsqrt
# Op: Rsqrt
#
# Name: functional_1_1/block_7_expand_1/convolution
# Op: Conv2D
#
# Name: functional_1_1/block_12_depthwise_relu_1/Relu6
# Op: Relu6
#
# Name: functional_1_1/block_4_project_1/convolution/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_7_expand_BN_1/Cast_2/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_12_expand_BN_1/batchnorm/add/y
# Op: Const
#
# Name: functional_1_1/block_7_expand_BN_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/block_12_expand_1/convolution
# Op: Conv2D
#
# Name: functional_1_1/block_2_depthwise_BN_1/Cast_3/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_7_expand_BN_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/bn_Conv1_1/batchnorm/Rsqrt
# Op: Rsqrt
#
# Name: functional_1_1/block_2_depthwise_BN_1/Cast/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_7_expand_relu_1/Relu6
# Op: Relu6
#
# Name: functional_1_1/block_12_expand_BN_1/Cast_2/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_2_depthwise_1/depthwise
# Op: DepthwiseConv2dNative
#
# Name: functional_1_1/block_4_project_BN_1/batchnorm/add/y
# Op: Const
#
# Name: functional_1_1/block_7_expand_BN_1/batchnorm/mul
# Op: Mul
#
# Name: functional_1_1/block_12_expand_BN_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/block_2_depthwise_BN_1/batchnorm/add/y
# Op: Const
#
# Name: functional_1_1/block_4_project_1/convolution
# Op: Conv2D
#
# Name: functional_1_1/block_7_expand_BN_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/block_12_expand_BN_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_2_depthwise_BN_1/Cast_1/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_4_project_BN_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/block_7_expand_BN_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/block_12_expand_relu_1/Relu6
# Op: Relu6
#
# Name: functional_1_1/bn_Conv1_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/block_2_depthwise_relu_1/Relu6
# Op: Relu6
#
# Name: functional_1_1/block_4_project_BN_1/Cast_2/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_7_expand_BN_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/block_12_expand_BN_1/batchnorm/mul
# Op: Mul
#
# Name: functional_1_1/block_2_depthwise_BN_1/Cast_2/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_4_project_BN_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/block_7_expand_BN_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/block_12_expand_BN_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/block_2_depthwise_BN_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/block_4_project_BN_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_12_expand_BN_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/block_2_depthwise_BN_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_7_depthwise_1/depthwise/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_12_expand_BN_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/block_4_project_BN_1/batchnorm/mul
# Op: Mul
#
# Name: functional_1_1/block_7_depthwise_1/depthwise
# Op: DepthwiseConv2dNative
#
# Name: functional_1_1/block_12_expand_BN_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/block_2_depthwise_BN_1/batchnorm/mul
# Op: Mul
#
# Name: functional_1_1/block_4_project_BN_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/block_7_depthwise_1/depthwise/Shape
# Op: Const
#
# Name: functional_1_1/block_12_depthwise_1/depthwise/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_2_depthwise_BN_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/bn_Conv1_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/block_4_project_BN_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/block_12_depthwise_1/depthwise
# Op: DepthwiseConv2dNative
#
# Name: functional_1_1/block_7_depthwise_BN_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_12_depthwise_1/depthwise/Shape
# Op: Const
#
# Name: functional_1_1/block_15_expand_relu_1/Relu6
# Op: Relu6
#
# ...
# Op: Placeholder
#
# Name: functional_1_1/block_16_expand_BN_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/block_8_project_BN_1/Cast_3/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_13_project_BN_1/Cast_2/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_16_expand_BN_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_8_project_1/convolution/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_13_project_1/convolution/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_16_expand_relu_1/Relu6
# Op: Relu6
#
# Name: functional_1_1/block_8_project_BN_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_16_expand_BN_1/batchnorm/mul
# Op: Mul
#
# Name: functional_1_1/block_8_project_BN_1/Cast_1/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_13_project_BN_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_16_expand_BN_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/block_13_project_BN_1/Cast_1/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_16_expand_BN_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/block_13_project_BN_1/batchnorm/Rsqrt
# Op: Rsqrt
#
# Name: functional_1_1/block_16_expand_BN_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/block_8_project_1/convolution/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_13_project_1/convolution/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_16_expand_BN_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/block_8_project_BN_1/batchnorm/Rsqrt
# Op: Rsqrt
#
# Name: functional_1_1/block_16_depthwise_1/depthwise/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_16_depthwise_BN_1/Cast_3/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_9_expand_BN_1/Cast/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_16_depthwise_1/depthwise/Shape
# Op: Const
#
# Name: functional_1_1/block_8_project_BN_1/Cast_1/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_13_project_BN_1/batchnorm/add/y
# Op: Const
#
# Name: functional_1_1/block_16_depthwise_BN_1/Cast_1/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_8_project_1/convolution
# Op: Conv2D
#
# Name: functional_1_1/block_13_project_1/convolution
# Op: Conv2D
#
# Name: functional_1_1/block_8_project_BN_1/Cast_2/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_16_depthwise_1/depthwise/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_8_project_BN_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/block_13_project_BN_1/Cast_2/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_16_depthwise_1/depthwise/dilation_rate
# Op: Const
#
# Name: functional_1_1/block_8_project_BN_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_13_project_BN_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/block_16_depthwise_BN_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/bn_Conv1_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/block_13_project_BN_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_16_depthwise_BN_1/batchnorm/Rsqrt
# Op: Rsqrt
#
# Name: functional_1_1/block_8_project_BN_1/batchnorm/mul
# Op: Mul
#
# Name: functional_1_1/block_8_project_BN_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/block_13_project_BN_1/batchnorm/mul
# Op: Mul
#
# Name: functional_1_1/block_8_project_BN_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/block_13_project_BN_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/block_16_depthwise_BN_1/Cast/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_8_project_BN_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/block_13_project_BN_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/block_16_depthwise_BN_1/batchnorm/add/y
# Op: Const
#
# Name: functional_1_1/block_8_project_BN_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/block_13_project_BN_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/block_16_depthwise_1/depthwise
# Op: DepthwiseConv2dNative
#
# Name: functional_1_1/block_13_project_BN_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/block_16_depthwise_BN_1/Cast_1/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_14_expand_BN_1/Cast_3/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/bn_Conv1_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/block_16_depthwise_BN_1/Cast_2/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_14_expand_BN_1/Cast/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_16_depthwise_BN_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/block_14_expand_BN_1/Cast_1/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_16_depthwise_BN_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_14_expand_BN_1/Cast_2/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_16_depthwise_relu_1/Relu6
# Op: Relu6
#
# Name: functional_1_1/expanded_conv_depthwise_1/depthwise/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_8_add_1/Add
# Op: AddV2
#
# Name: functional_1_1/block_14_expand_1/convolution/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_16_depthwise_BN_1/batchnorm/mul
# Op: Mul
#
# Name: functional_1_1/block_16_depthwise_BN_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/block_14_expand_BN_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_16_depthwise_BN_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/expanded_conv_depthwise_1/depthwise/Shape
# Op: Const
#
# Name: functional_1_1/block_9_expand_BN_1/batchnorm/add/y
# Op: Const
#
# Name: functional_1_1/block_14_expand_BN_1/Cast_1/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_16_depthwise_BN_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/expanded_conv_depthwise_BN_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_9_expand_BN_1/Cast_3/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_14_expand_BN_1/batchnorm/Rsqrt
# Op: Rsqrt
#
# Name: functional_1_1/block_16_depthwise_BN_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/block_9_expand_BN_1/Cast_2/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_14_expand_1/convolution/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_9_expand_BN_1/Cast_1/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_14_depthwise_BN_1/Cast_2/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_16_project_BN_1/Cast_3/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_9_expand_1/convolution/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_14_expand_relu_1/Relu6
# Op: Relu6
#
# Name: functional_1_1/block_9_depthwise_BN_1/batchnorm/Rsqrt
# Op: Rsqrt
#
# Name: functional_1_1/block_16_project_BN_1/Cast/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_9_expand_BN_1/Cast_2/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_14_expand_BN_1/batchnorm/add/y
# Op: Const
#
# Name: functional_1_1/block_16_project_BN_1/Cast_1/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_9_expand_BN_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_14_expand_1/convolution
# Op: Conv2D
#
# Name: functional_1_1/block_16_project_BN_1/Cast_2/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_9_expand_1/convolution/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_14_depthwise_BN_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/block_16_project_1/convolution/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_9_depthwise_BN_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/block_14_expand_BN_1/Cast_2/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_9_expand_BN_1/batchnorm/Rsqrt
# Op: Rsqrt
#
# Name: functional_1_1/block_14_expand_BN_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/block_16_project_BN_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_14_expand_BN_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_16_project_BN_1/Cast_1/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_9_depthwise_BN_1/batchnorm/add/y
# Op: Const
#
# Name: functional_1_1/block_16_project_BN_1/batchnorm/Rsqrt
# Op: Rsqrt
#
# Name: functional_1_1/block_9_expand_1/convolution
# Op: Conv2D
#
# Name: functional_1_1/block_14_expand_BN_1/batchnorm/mul
# Op: Mul
#
# Name: functional_1_1/block_16_project_1/convolution/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_9_expand_BN_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/block_14_expand_BN_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/block_9_expand_BN_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_14_expand_BN_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/block_9_expand_relu_1/Relu6
# Op: Relu6
#
# Name: functional_1_1/block_14_expand_BN_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/block_9_expand_BN_1/batchnorm/mul
# Op: Mul
#
# Name: functional_1_1/block_14_expand_BN_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/block_16_project_BN_1/batchnorm/add/y
# Op: Const
#
# Name: functional_1_1/block_9_expand_BN_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/block_14_depthwise_1/depthwise/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_16_project_1/convolution
# Op: Conv2D
#
# Name: functional_1_1/block_9_expand_BN_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/block_14_depthwise_BN_1/Cast_3/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/bn_Conv1_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_9_expand_BN_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/block_14_depthwise_1/depthwise/Shape
# Op: Const
#
# Name: functional_1_1/block_16_project_BN_1/Cast_2/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/bn_Conv1_1/batchnorm/add/y
# Op: Const
#
# Name: functional_1_1/block_9_expand_BN_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/block_14_depthwise_BN_1/Cast_1/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_16_project_BN_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/block_16_project_BN_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_9_depthwise_1/depthwise/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_14_depthwise_1/depthwise/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_9_depthwise_BN_1/Cast_2/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_14_depthwise_1/depthwise/dilation_rate
# Op: Const
#
# Name: functional_1_1/block_16_project_BN_1/batchnorm/mul
# Op: Mul
#
# Name: functional_1_1/expanded_conv_depthwise_1/depthwise/dilation_rate
# Op: Const
#
# Name: functional_1_1/block_9_depthwise_1/depthwise/Shape
# Op: Const
#
# Name: functional_1_1/block_14_depthwise_BN_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_16_project_BN_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/block_9_depthwise_BN_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_14_depthwise_BN_1/batchnorm/Rsqrt
# Op: Rsqrt
#
# Name: functional_1_1/block_16_project_BN_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/block_9_depthwise_BN_1/Cast_1/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_16_project_BN_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/block_9_depthwise_1/depthwise/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_14_depthwise_relu_1/Relu6
# Op: Relu6
#
# Name: functional_1_1/block_16_project_BN_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/block_9_depthwise_1/depthwise/dilation_rate
# Op: Const
#
# Name: functional_1_1/block_14_depthwise_BN_1/Cast/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_14_depthwise_BN_1/batchnorm/add/y
# Op: Const
#
# Name: functional_1_1/block_14_depthwise_1/depthwise
# Op: DepthwiseConv2dNative
#
# Name: functional_1_1/block_14_depthwise_BN_1/Cast_1/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/Conv_1_bn_1/Cast_1/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_9_depthwise_BN_1/Cast_3/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_14_depthwise_BN_1/Cast_2/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/Conv_1_bn_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_9_depthwise_BN_1/Cast/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_14_depthwise_BN_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/Conv_1_bn_1/Cast_2/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/bn_Conv1_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/block_9_depthwise_1/depthwise
# Op: DepthwiseConv2dNative
#
# Name: functional_1_1/block_14_depthwise_BN_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/Conv_1_bn_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/dense_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_9_depthwise_BN_1/Cast_1/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_14_depthwise_BN_1/batchnorm/mul
# Op: Mul
#
# Name: functional_1_1/Conv_1_1/convolution/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_9_depthwise_BN_1/Cast_2/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_14_depthwise_BN_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/Conv_1_bn_1/batchnorm/Rsqrt
# Op: Rsqrt
#
# Name: functional_1_1/block_9_depthwise_relu_1/Relu6
# Op: Relu6
#
# Name: functional_1_1/block_14_depthwise_BN_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/block_9_depthwise_BN_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_14_depthwise_BN_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/block_9_depthwise_BN_1/batchnorm/mul
# Op: Mul
#
# Name: functional_1_1/Conv_1_1/convolution/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_9_depthwise_BN_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/block_14_project_BN_1/Cast/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_9_depthwise_BN_1/batchnorm/mul_2
# Op: Mul
#
# Name: functional_1_1/block_14_project_BN_1/Cast_2/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_9_depthwise_BN_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/block_9_depthwise_BN_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/block_14_project_BN_1/Cast_1/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/Conv_1_bn_1/Cast_3/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_14_project_BN_1/Cast_3/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/Conv_1_1/convolution
# Op: Conv2D
#
# Name: functional_1_1/block_14_project_1/convolution/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/Conv_1_bn_1/batchnorm/sub
# Op: Sub
#
# Name: functional_1_1/block_9_project_BN_1/Cast_2/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_14_project_BN_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/Conv_1_bn_1/Cast/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_9_project_BN_1/Cast/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_14_project_BN_1/Cast_1/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/Conv_1_bn_1/Cast_1/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_9_project_BN_1/Cast_3/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_14_project_BN_1/batchnorm/add/y
# Op: Const
#
# Name: functional_1_1/Conv_1_bn_1/batchnorm/add/y
# Op: Const
#
# Name: functional_1_1/block_9_project_1/convolution
# Op: Conv2D
#
# Name: functional_1_1/Conv_1_bn_1/Cast_2/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/block_9_project_BN_1/Cast_1/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_14_project_1/convolution/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/Conv_1_bn_1/batchnorm/add_1
# Op: AddV2
#
# Name: functional_1_1/block_9_project_1/convolution/ReadVariableOp
# Op: ReadVariableOp
#
# Name: functional_1_1/block_14_project_BN_1/batchnorm/add
# Op: AddV2
#
# Name: functional_1_1/Conv_1_bn_1/Cast_3/ReadVariableOp/resource
# Op: Placeholder
#
# Name: functional_1_1/Conv_1_bn_1/batchnorm/mul
# Op: Mul
#
# Name: functional_1_1/Conv_1_bn_1/batchnorm/mul_1
# Op: Mul
#
# Name: functional_1_1/block_14_project_1/convolution
# Op: Conv2D
